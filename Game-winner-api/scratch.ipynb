# %%
from datetime import datetime, timedelta
from nba_api.stats.endpoints import scoreboard, scoreboardv2
import pandas as pd

# get yesterday's date
yesterday = datetime.now() - timedelta(days=1)
yesterday_str = yesterday.strftime('%m/%d/%Y')

# get scoreboard for yesterday's date
games = scoreboardv2.ScoreboardV2(day_offset=0, game_date=yesterday_str).line_score.get_data_frame()

games.head()
# loop through each game and print the winner
# for index, game in games.iterrows():
#     print(f"{game['VISITOR_TEAM_NAME']} {game['VISITOR_TEAM_SCORE']} - {game['HOME_TEAM_SCORE']} {game['HOME_TEAM_NAME']}")
#     if game['VISITOR_TEAM_SCORE'] > game['HOME_TEAM_SCORE']:
#         print(f"Winner: {game['VISITOR_TEAM_NAME']}")
#     else:
#         print(f"Winner: {game['HOME_TEAM_NAME']}")
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID     TEAM_ID  \
# 0  2023-05-06T00:00:00              1  0042200203  1610612752
# 1  2023-05-06T00:00:00              1  0042200203  1610612748
# 2  2023-05-06T00:00:00              2  0042200233  1610612744
# 3  2023-05-06T00:00:00              2  0042200233  1610612747
#
#   TEAM_ABBREVIATION TEAM_CITY_NAME TEAM_NAME TEAM_WINS_LOSSES  PTS_QTR1  \
# 0               NYK       New York    Knicks              1-2        21
# 1               MIA          Miami      Heat              2-1        29
# 2               GSW   Golden State  Warriors              1-2        30
# 3               LAL    Los Angeles    Lakers              2-1        23
#
#    PTS_QTR2  ...  PTS_OT8  PTS_OT9  PTS_OT10  PTS  FG_PCT  FT_PCT  FG3_PCT  \
# 0        23  ...        0        0         0   86   0.341   0.727    0.200
# 1        29  ...        0        0         0  105   0.389   0.903    0.219
# ...

# %%
def get_winner(group):
    points = group['PTS'].idxmax()
    winner = group.loc[points, ['GAME_DATE_EST', 'GAME_SEQUENCE', 'TEAM_ID']]
    return winner

winners = games.groupby('GAME_ID').apply(get_winner)
print(winners)
# Out:
#                   GAME_DATE_EST  GAME_SEQUENCE     TEAM_ID
# GAME_ID
# 0042200203  2023-05-06T00:00:00              1  1610612748
# 0042200233  2023-05-06T00:00:00              2  1610612747

# %%
date = datetime.now()
date_string = date.strftime('%m/%d/%Y')
gamefinder = scoreboardv2.ScoreboardV2(day_offset=0, game_date=date_string)
games = gamefinder.line_score.get_data_frame()

# %%
games.head()
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID     TEAM_ID  \
# 0  2023-05-07T00:00:00              1  0042200214  1610612738
# 1  2023-05-07T00:00:00              1  0042200214  1610612755
# 2  2023-05-07T00:00:00              2  0042200224  1610612743
# 3  2023-05-07T00:00:00              2  0042200224  1610612756
#
#   TEAM_ABBREVIATION TEAM_CITY_NAME TEAM_NAME TEAM_WINS_LOSSES PTS_QTR1  \
# 0               BOS         Boston   Celtics              2-1     None
# 1               PHI   Philadelphia     76ers              1-2     None
# 2               DEN         Denver   Nuggets              2-1     None
# 3               PHX        Phoenix      Suns              1-2     None
#
#   PTS_QTR2  ... PTS_OT8 PTS_OT9 PTS_OT10   PTS FG_PCT FT_PCT FG3_PCT   AST  \
# 0     None  ...    None    None     None  None   None   None    None  None
# 1     None  ...    None    None     None  None   None   None    None  None
# ...

# %%
winners = games.groupby('GAME_ID').apply(get_winner)
# winners = winners.reset_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\theaj\anaconda3\envs\NBA\lib\site-packages\pandas\core\groupby\groupby.py:1567, in GroupBy.apply(self, func, *args, **kwargs)
#    1564     with rewrite_warning(
#    1565         old_msg, FutureWarning, new_msg
#    1566     ) if is_np_func else nullcontext():
# -> 1567         result = self._python_apply_general(f, self._selected_obj)
#    1568 except TypeError:
#    1569     # gh-20949
#    1570     # try again, with .apply acting as a filtering
#    (...)
#    1574     # fails on *some* columns, e.g. a numeric operation
#    1575     # on a string grouper column
#
# File c:\Users\theaj\anaconda3\envs\NBA\lib\site-packages\pandas\core\groupby\groupby.py:1629, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1601 """
#    1602 Apply function f in python space
#    1603
# ...
